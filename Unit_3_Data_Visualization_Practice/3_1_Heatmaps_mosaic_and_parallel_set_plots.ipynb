# %%
import matplotlib.pyplot as plt

import numpy as np 

import seaborn as sns

# %matplotlib inline

# %%
prog_language = ['Python', 'C++', 'Java']
sex = ['Male', 'Female']

amounts = np.array([[20,11,10], [15,7,11]])

# %%
fig, ax = plt.subplots()

sns.heatmap(amounts, annot=True,ax=ax)

ax.set_xticklabels(prog_language)
ax.set_yticklabels(sex)

# show figure
plt.show()

# %%
import matplotlib.pyplot as plt

import seaborn as sns

from statsmodels.graphics.mosaicplot import mosaic

# %%
tips = sns.load_dataset("tips")

# %%mosaic plot of sex, smoker and time
mosaic(tips, ['sex','smoker','time'])

plt.show()

# %%
import plotly.express as px
import seaborn as sns

# %%
titanic = sns.load_dataset("titanic")

# %% parallel sets plot
fig = px.parallel_categories(titanic, \
    dimensions=['sex', 'class', 'alive'], \
    color="survived", \
    labels={'sex':'Passenger sex', \
        'class':'Class of passenger', \
        'alive':'Survived'})

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 11
#       3 # %% parallel sets plot
#       4 fig = px.parallel_categories(titanic, \
#       5     dimensions=['sex', 'class', 'alive'], \
#       6     color="survived", \
#       7     labels={'sex':'Passenger sex', \
#       8         'class':'Class of passenger', \
#       9         'alive':'Survived'})
# ---> 11 fig.show()
#
# File c:\Users\mrosk\.conda\envs\ml311\Lib\site-packages\plotly\basedatatypes.py:3410, in BaseFigure.show(self, *args, **kwargs)
#    3377 """
#    3378 Show a figure using either the default renderer(s) or the renderer(s)
#    3379 specified by the renderer argument
#    (...)
#    3406 None
#    3407 """
#    3408 import plotly.io as pio
# -> 3410 return pio.show(self, *args, **kwargs)
#
# File c:\Users\mrosk\.conda\envs\ml311\Lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
